# %% [markdown]
# <a href="https://colab.research.google.com/github/ahlem449/gomycode/blob/main/last_checkpoint.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <center> Last chechpoint: **Let's rectify our errors**
#
# ---

# %%
liste=["hello", 5, True]
len(liste)
# Out:
# 3

# %%
import numpy

# %%
import pandas as pd

# %%
print("hello")
# Out:
# hello

# %%
dic={True:"hello", 5:"bye", 'false':"thank you"}
dic1=dic[5]
dic1
# Out:
# 'bye'

# %%
liste=["hello", 5, True]
for i in liste :
   print(i)
# Out:
# hello
# 5
# True

# %%
it=iter([1,2,3])
next(it)
next(it)
next(it)
# Out:
# 3

# %%
True + True
# Out:
# 2

# %%
1+1
# Out:
# 2

# %%
int(3)
# Out:
# 3

# %%
x=69/2
print (x)
# Out:
# 34.5
