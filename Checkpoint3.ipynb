# %% [markdown]
# # Question 1:

# %%
#x= int(input('entre nomber:'))
my_list = [2, 3, 6] 
print(my_list[0]*my_list[1]*my_list[2])
# Out:
# 36

# %% [markdown]
# # Question 2:

# %%
R1= [(2, 5), (1, 2), (4, 4), (2, 3), (2, 1)]
R1.sort(key = lambda x: x[1])
print (R1)
# Out:
# [(2, 1), (1, 2), (2, 3), (4, 4), (2, 5)]

# %% [markdown]
# # Question 3:

# %%
x = {'a': 100, 'b': 200, 'c': 300}
y = {'a': 300, 'b': 200, 'd': 400}
for key in y:
    if key in x:
        x[key] = y[key] + x[key]
    else:
        x[key]=y[key]
        print(x)
# Out:
# {'a': 400, 'b': 400, 'c': 300, 'd': 400}

# %% [markdown]
# # Question 4:

# %%
my_dictionary = {}
r = int(input('donner n :'))
for i in range (1,r+1):
    my_dictionary[i]=i*i
print(my_dictionary)
# Out:
# donner n :9
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81}

# %% [markdown]
# # Question 5:

# %%
list= [('item1', '12.20'), ('item2', '15.10'), ('item3', '24.5')]
list1=reversed(list)
tuple(list1)
# Out:
# (('item3', '24.5'), ('item2', '15.10'), ('item1', '12.20'))
